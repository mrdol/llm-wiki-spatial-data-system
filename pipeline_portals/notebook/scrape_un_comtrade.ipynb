# %% [markdown]
# # Scrape Un Comtrade
#
# Notebook doublure of `pipeline_portals/python/scrape_un_comtrade.py`. The code cell loads the same script logic without automatically running `main()`.

# %%
"""Prepare UN Comtrade portal scraping seeds for later discovery phases."""

from __future__ import annotations

import sys
from pathlib import Path

SCRIPT_DIR = Path(__file__).resolve().parent
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from portal_common import run_portal_cli


PREFERRED_LAYER_TYPES = (
    "portal",
    "methodology_page",
    "record_layout",
    "api_catalogue",
    "api_portal_reference",
)


def main() -> None:
    """Entry point for the non-executed UN Comtrade portal plan."""

    run_portal_cli(
        warehouse_id="un_comtrade",
        preferred_layer_types=PREFERRED_LAYER_TYPES,
        script_label="Prepare UN Comtrade portal scraping plan.",
        extra_notes=(
            "UN Comtrade raw API behavior has been unstable in the current environment, so later phases should capture HTTP headers and content types explicitly.",
            "Methodology, record-layout, and live API routes should remain separate parser targets.",
        ),
    )


# In notebook mode, call main() manually only if you want CLI parsing.
# main()
