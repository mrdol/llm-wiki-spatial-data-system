# %% [markdown]
# # Scrape Oecd
#
# Notebook doublure of `pipeline_portals/python/scrape_oecd.py`. The code cell loads the same script logic without automatically running `main()`.

# %%
"""Prepare OECD portal scraping seeds for later discovery phases."""

from __future__ import annotations

import sys
from pathlib import Path

SCRIPT_DIR = Path(__file__).resolve().parent
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from portal_common import run_portal_cli


PREFERRED_LAYER_TYPES = (
    "publication_portal",
    "api",
    "catalog",
)


def main() -> None:
    """Entry point for the non-executed OECD portal plan."""

    run_portal_cli(
        warehouse_id="oecd",
        preferred_layer_types=PREFERRED_LAYER_TYPES,
        script_label="Prepare OECD portal scraping plan.",
        extra_notes=(
            "OECD publication pages and OECD SDMX registry references should be parsed as separate discovery objects.",
            "Discontinued series may require archive routing instead of public registry routing in later phases.",
        ),
    )


# In notebook mode, call main() manually only if you want CLI parsing.
# main()
